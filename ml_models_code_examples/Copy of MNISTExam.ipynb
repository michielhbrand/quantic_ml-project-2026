# %% [markdown]
# ## MNIST
# Using the [MNIST](http://yann.lecun.com/exdb/mnist/) database, we'll train a model that can recognize handwritten digits.

# %%
import torch
from torch.nn.modules.loss import CrossEntropyLoss
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let's use the GPU
# So you don't have to restart the runtime later in the notebook, let's tell Colab to use the GPU for hardware acceleration now.
#
# Go to Runtime > Change Runtime Type and select GPU, then continue.

# %%
# device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu?')
print("Device: ", device)
# Out:
# Device:  cuda

# %%
# hyperparameters
features = 784 # images are 28x28
hidden_size = 100 # how many neurons to have in our hidden layer
num_labels = 10 # digits from 0-9
num_epochs = 10
batch_size = 100
learning_rate = 0.001

# This data comes straight from PyTorch's Computer Vision library
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

# dataloaders
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False) # no need to shuffle the test set

# %%
# looking at the data
examples = iter(train_loader)
samples, labels = next(examples)
print(samples.shape, labels.shape)

for i in range(6):
  plt.subplot(2,3,i+1)
  plt.imshow(samples[i][0], cmap='gray')
  plt.show()
# Out:
# torch.Size([100, 1, 28, 28]) torch.Size([100])

# %%
class NeuralNet(nn.Module):
  def __init__(self, features, hidden_size, num_labels):
    super(NeuralNet, self).__init__()
    self.l1 = nn.Linear(features, hidden_size) # first layer

    self.relu = nn.ReLU()
    self.l2 = nn.Linear(hidden_size, num_labels) # hidden layer to output

  def forward(self, x):
    out = self.l1(x)
    out = self.relu(out)
    out = self.l2(out)
    return out

model = NeuralNet(features, hidden_size, num_labels).to(device)

# %%
# loss and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# training loop
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
  for i, (images, labels) in enumerate(train_loader):
    images = images.reshape(-1, 28*28).to(device) # reshape turns the 28x28 squares into a single (1,784) vector
    labels = labels.to(device)

    # forward pass
    outputs = model(images)
    loss = loss_function(outputs, labels)

    # backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (i + 1) % 100 == 0:
      print(f'epoch {epoch+1} / {num_epochs}, batch {i+1}/{n_total_steps}, loss = {loss.item():.4f}')
      if(i+1  == n_total_steps):
        print("epoch complete!")
# Out:
# epoch 1 / 10, batch 100/600, loss = 2.2837
# epoch 1 / 10, batch 200/600, loss = 2.2616
# epoch 1 / 10, batch 300/600, loss = 2.2488
# epoch 1 / 10, batch 400/600, loss = 2.2378
# epoch 1 / 10, batch 500/600, loss = 2.2226
# epoch 1 / 10, batch 600/600, loss = 2.2004
# epoch complete!
# epoch 2 / 10, batch 100/600, loss = 2.1892
# epoch 2 / 10, batch 200/600, loss = 2.1707
# epoch 2 / 10, batch 300/600, loss = 2.1611
# epoch 2 / 10, batch 400/600, loss = 2.1368
# epoch 2 / 10, batch 500/600, loss = 2.0883
# epoch 2 / 10, batch 600/600, loss = 2.0803
# epoch complete!
# epoch 3 / 10, batch 100/600, loss = 2.0632
# epoch 3 / 10, batch 200/600, loss = 2.0052
# epoch 3 / 10, batch 300/600, loss = 1.9714
# epoch 3 / 10, batch 400/600, loss = 1.9649
# epoch 3 / 10, batch 500/600, loss = 1.9460
# epoch 3 / 10, batch 600/600, loss = 1.8976
# epoch complete!
# epoch 4 / 10, batch 100/600, loss = 1.8441
# epoch 4 / 10, batch 200/600, loss = 1.8567
# epoch 4 / 10, batch 300/600, loss = 1.8157
# epoch 4 / 10, batch 400/600, loss = 1.7638
# epoch 4 / 10, batch 500/600, loss = 1.7031
# epoch 4 / 10, batch 600/600, loss = 1.6832
# epoch complete!
# epoch 5 / 10, batch 100/600, loss = 1.6676
# epoch 5 / 10, batch 200/600, loss = 1.5926
# epoch 5 / 10, batch 300/600, loss = 1.6643
# epoch 5 / 10, batch 400/600, loss = 1.5720
# epoch 5 / 10, batch 500/600, loss = 1.4841
# epoch 5 / 10, batch 600/600, loss = 1.5534
# epoch complete!
# epoch 6 / 10, batch 100/600, loss = 1.5136
# epoch 6 / 10, batch 200/600, loss = 1.4606
# epoch 6 / 10, batch 300/600, loss = 1.4659
# epoch 6 / 10, batch 400/600, loss = 1.4374
# epoch 6 / 10, batch 500/600, loss = 1.3725
# epoch 6 / 10, batch 600/600, loss = 1.3744
# epoch complete!
# epoch 7 / 10, batch 100/600, loss = 1.2830
# epoch 7 / 10, batch 200/600, loss = 1.2596
# epoch 7 / 10, batch 300/600, loss = 1.2731
# epoch 7 / 10, batch 400/600, loss = 1.2693
# epoch 7 / 10, batch 500/600, loss = 1.2067
# epoch 7 / 10, batch 600/600, loss = 1.2263
# epoch complete!
# epoch 8 / 10, batch 100/600, loss = 1.1465
# epoch 8 / 10, batch 200/600, loss = 1.2012
# epoch 8 / 10, batch 300/600, loss = 1.1685
# epoch 8 / 10, batch 400/600, loss = 1.1690
# epoch 8 / 10, batch 500/600, loss = 1.0981
# epoch 8 / 10, batch 600/600, loss = 1.0329
# epoch complete!
# epoch 9 / 10, batch 100/600, loss = 1.1309
# epoch 9 / 10, batch 200/600, loss = 1.0218
# epoch 9 / 10, batch 300/600, loss = 0.9761
# epoch 9 / 10, batch 400/600, loss = 0.9398
# epoch 9 / 10, batch 500/600, loss = 0.8947
# epoch 9 / 10, batch 600/600, loss = 0.9150
# epoch complete!
# epoch 10 / 10, batch 100/600, loss = 0.9579
# epoch 10 / 10, batch 200/600, loss = 0.8381
# epoch 10 / 10, batch 300/600, loss = 0.8529
# epoch 10 / 10, batch 400/600, loss = 0.9277
# epoch 10 / 10, batch 500/600, loss = 0.9531
# epoch 10 / 10, batch 600/600, loss = 0.8717
# epoch complete!

# %%
with torch.no_grad():
      n_correct = 0
      n_samples = 0
      for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images).to(device)
        _, predictions = torch.max(outputs, 1) # we don't need the first value returned by torch.max, so discard it via the _
        n_samples += labels.shape[0]
        n_correct += (predictions == labels).sum().item()

      acc = 100.0 * n_correct / n_samples
      print(f'accuracy = {acc}')
# Out:
# accuracy = 82.73
